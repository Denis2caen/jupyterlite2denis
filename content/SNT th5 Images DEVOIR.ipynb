# %% [markdown]
# <h1 style="color:red">Thème 5 : La photographie numérique</h1>
#
# <h1 style="color:blue"> Devoir 2nde8 23-05-2022</h1>
#
# Les questions sont toutes dans ce **Notebook Jupyter.**
#
#
# - A la fin de la séance, cliquer sur **`enregistrer`**, puis sur **`Rendre le devoir`**.
# ><p style="color:red"> voir les instructions en bas de page</p>
#
# <hr>
#
# Vous pouvez bien sûr consulter le notebook utilisé en classe pour retrouver des lignes de code ou des explications.<br>
# Le notehbook a été partag" en deux notebook :<br>
# - <a href="https://capytale2.ac-paris.fr/web/c/5ff5-554153">SNT Traitement d'images (1)</a> - code sous `Capytale` <a href="https://capytale2.ac-paris.fr/web/c/5ff5-554153">`5ff5-554153`.</a><br>
# - <a href="https://capytale2.ac-paris.fr/web/c/5ff5-554153">SNT Traitement d'images (2)</a> - code sous `Capytale` <a href="https://capytale2.ac-paris.fr/web/c/49bb-535266">`49bb-535266`.</a>

# %% [markdown]
# *----------------------------------------------------------------------------------------------------------------------*

# %% [markdown]
# Les images vont être créées ou manipulées par l'outil **Image** de la librairie **PIL** de Python.<br>
# Le code doit donc commencer par <code>from PIL import Image</code>
#
# <h3 style="color:red">Rappels de quelques-unes des fonctions du module <em>Image</em> de la librairie <em>PIL</em> :</h3>
#
#
# commande       |   résultat
# :-------------: |:-------------
# `Image.open("Mon_Image.jpg")` |   **Ouverture** du fichier *Mon_Image.jpg*
# `img1=Image.open("Mon_Image.jpg")`| **Ouverture** du fichier *Mon_Image.jpg* et **création** de l'objet *img1*
# `Image.new("RGB", (200,100))`| Création d'une **nouvelle image** (mode RGB et de taille 200px (largeur) sur 100px (hauteur))<br>(d'abord le nombre de colonnes puis le nombre de lignes)
# `.getpixel((i, j))`     | **récupère** la **couleur du pixel** (i,j) de l'image img1 <br> sous la forme d'un tuple (r, v, b)
# `.putpixel((i, j), (r,v,b))` |  **attribue la couleur** (r,v,b) au pixel (i,j)
# `img1.save("img2.jpg")` | **enregistre** l'**image** créée sous le sous nom *img2.jpg*
# `img2.show()`| montre l'image img2 dans le lecteur par défaut de l'ordinateur
# `ìmg2`| montre (affiche) l'image img2 directement dans le notebook
#
# Toutes les commandes qui sont précédées de `ìmg1` s'appliquent à l'objet <em>img1</em>, il faut donc qu'il ait été déclaré avant.
#
# #### Les informations de l'image
#
# Il est possible d'accéder aux caractéristiques de l'image avec les commandes suivantes :
#
# >  **.format**  : format de la source de l’image,
# >  **.size**  : taille de l’image(largeur, hauteur en pixels),
# >  **.mode**  : noms et type des différents canaux de l’image (« RGB » = 3 canaux Rouge, Vert et Bleu – « L » = un canal pour niveaux de gris – …).

# %% [markdown]
# <h3 style="color:red">Chaque pixel d'une image est repéré par ses <strong>coordonnées x,y</strong>.</h3>
# <br>x correspond au numéro de colonne et y au numéro de ligne.
#
#
# <img src="https://capytale2.ac-paris.fr/web/sites/default/files/2022/05-22/0-43-03/imagenb.jpg" alt="coordonnées des pixels sur une image" width="40%">
#
# Comme vous pouvez le constater sur le schéma ci-dessus, le pixel de coordonnées (0,0) se trouve en haut à gauche de l'image. Si l'image fait 800 pixels de large et 600 pixels de haut, le pixel ayant pour coordonnées (100,500) sera en bas à gauche et le pixel(400,300) sera au milieu de l'image.

# %% [markdown]
# *----------------------------------------------------------------------------------------------------------------------*

# %% [markdown]
# <h3 style="color:blue">Exercice 1. Constitution d'une image simple.</h3>
#
# <div class="alert alert-success" style="border-left: 15px solid #336633;">
# <h3 style="color:336633;background-color:#99FFCC">Travail 1</h3>
#
# >Créer une image entièrement orange, de largeur 250 pixels et de hauteur 100 pixels.<br>
# >Écrire le code dans la cellule vide ci-après.
#
# L'enregistrer sous le nom **_imageorange.png_**.

# %% [markdown]
# <div class="alert alert-danger" style="border-left: 15px solid #a94442;">
# <details style="details[open] summary::-webkit-details-marker { color:#eaeaea; background:#eaeaea; outline: 2px solid #ADCA48;}"><summary style="summary::-webkit-details-marker { color:#ADCA48; background:#ADCA48;} ">
# Une petite AIDE ? Alors clique ici !  </summary>
# En panne sur les codes de couleurs ?<br>
# Visite le site suivant :<br>
#
# > http://www.proftnj.com/RGB3.htm

# %% [markdown]
# <h3 style="color:blue">Exercice 2. Constitution d'un drapeau.</h3>
#
# >Pour rappel, voici ci-dessous un exemple de code qui permet de faire un drapeau.
#
# <div class="alert alert-success" style="border-left: 15px solid #336633;">
# <h3 style="color:336633;background-color:#99FFCC">Travail 2</h3>
#
# >Dans la cellule vide ci-après, écrire le code qui permet de faire le drapeau <u>indiqué par le professeur</u> (Monaco, Pologne ou Ukraine).
#
# <img src="https://capytale2.ac-paris.fr/web/sites/default/files/2022/05-22/1-39-29/Drapeaux_Monaco_Pologne_Ukraine.png" alt="drapeaux des trois pays" width="40%">
#
#
# L'enregistrer sous le nom **_pays.png_**. _(remplacer pays par le nom du pays correspondant)_

# %%
from PIL import Image
col=120
lgn=100
img=Image.new("RGB", (col,lgn))  # les nombres de colonnes et de lignes ont été définis aux deux lignes précédentes
for y in range (lgn):
        for x in range (col//3):  # Le symbole // est la division entière dans Python
            img.putpixel((x,y),(0,0,255))
        for x in range ((col//3), (2*col//3)):
            img.putpixel((x,y),(255,255,255))
        for x in range ((2*col//3), col):
            img.putpixel((x,y),(255,0,0))
img.save("france.png")
img

# %% [markdown]
# <hr>
#
# <h2 style="color:blue">Travail sur de réelles photos</h2>

# %% [markdown]
# ### L'image qui va être utilisée est *bassecour.jpg*
#
# Il faut d'abord la charger avec la ligne de code <br>
# `Image.open("Mon_Image.jpg")`.
#
# <h3 style="color:blue">Exercice 3. Taille.</h3>
# <div class="alert alert-success" style="border-left: 15px solid #336633;">
# <h3 style="color:336633;background-color:#99FFCC">Travail 3</h3>
#     Écrire le programme qui permet d'ouvrir cette image, puis afficher sa taille (largeur et hauteur en pixels).

# %% [markdown]
# <h3 style="color:blue">Exercice 4. Changement de couleurs.</h3>
#
# <div class="alert alert-success" style="border-left: 15px solid #336633;">
# <h3 style="color:336633;background-color:#99FFCC">Travail 4</h3>
#     Écrire un programme qui inverse les valeurs des canaux vert et rouge sans modifier la valeur du canal bleu.

# %% [markdown]
# <h3 style="color:blue">Exercice 5. Rogner ou recadrer.</h3>
#
# <div class="alert alert-success" style="border-left: 15px solid #336633;">
# <h3 style="color:336633;background-color:#99FFCC">Travail 5</h3>
#     But : découper une partie de l'image avec la commande <code><strong>crop</strong></code>.
#
# >  **img2 = img.crop((gauche, haut, droite, bas))**  : découpe l'image **img** entre les deux points de coordonnées (gauche, haut) et (droite, bas) et l'enregistre sous le nom d'objet img2.<br>
# >_Les coordonnées du point (gauche, haut) et du point (droite, bas) sont en pixels._
#
# <p style="color:red; font-style:italic">Demander au professeur la partie à découper.</p>
#
# _Cette image ne doit pas comporter de modifications de couleurs et doit être bien cadrée._

# %% [markdown]
# > ## A la fin de la séance, bien penser à cliquer sur `Rendre le devoir` après l'avoir enregistré.
# ><p style="color:green"> Votre page pourra alors être commentée et éventuellement notée par le professeur</p>
# <hr>
